# %%
import urllib.request
import json
import numpy as np
import pandas as pd
import altair
import pprint

# %%
base = 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/'
url = '/Persoon?&$expand=FractieZetelPersoon($expand=FractieZetel($expand=Fractie))&$count=true'
end = '&$count=true&$format=application/json;odata.metadata=full'
response = urllib.request.urlopen(base+url)
data = response.read()      # a `bytes` object
data = json.loads(data)

# %%
data.keys()
# Out:
# dict_keys(['@odata.context', '@odata.count', 'value', '@odata.nextLink'])

# %%
pprint(data['value'][0]['FractieZetelPersoon'][0]['FractieZetel'])
# Out:
# {'@odata.editLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/FractieZetel(0d23189b-ead4-4576-8cbd-6db0ac1ccc04)',
#  '@odata.id': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/FractieZetel(0d23189b-ead4-4576-8cbd-6db0ac1ccc04)',
#  '@odata.type': '#TK.DA.GGM.OData.FractieZetel',
#  'ApiGewijzigdOp': '2019-04-01T12:49:16.857Z',
#  'ApiGewijzigdOp@odata.type': '#DateTimeOffset',
#  'Fractie': {'#TK.DA.GGM.OData.Resource': {'target': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/TK.DA.GGM.OData.Resource()',
#                                            'title': 'Resource'},
#              '@odata.editLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)',
#              '@odata.id': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)',
#              '@odata.type': '#TK.DA.GGM.OData.Fractie',
#              'AantalStemmen': 1372941,
#              'AantalZetels': 20,
#              'ActiviteitActor@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/ActiviteitActor/$ref',
#              'ActiviteitActor@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/ActiviteitActor',
#              'Afkorting': 'PVV',
#              'ApiGewijzigdOp': '2019-04-01T12:48:07.62Z',
#              'ApiGewijzigdOp@odata.type': '#DateTimeOffset',
#              'CommissieVastVacature@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/CommissieVastVacature/$ref',
#              'CommissieVastVacature@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/CommissieVastVacature',
#              'CommissieVervangerVacature@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/CommissieVervangerVacature/$ref',
#              'CommissieVervangerVacature@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/CommissieVervangerVacature',
#              'ContentLength': 4484,
#              'ContentType': 'image/jpeg',
#              'DatumActief': '2006-11-30T00:00:00+01:00',
#              'DatumActief@odata.type': '#DateTimeOffset',
#              'DatumInactief': None,
#              'DocumentActor@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/DocumentActor/$ref',
#              'DocumentActor@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/DocumentActor',
#              'FractieAanvullendGegeven@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/FractieAanvullendGegeven/$ref',
#              'FractieAanvullendGegeven@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/FractieAanvullendGegeven',
#              'FractieZetel@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/FractieZetel/$ref',
#              'FractieZetel@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/FractieZetel',
#              'GewijzigdOp': '2019-04-01T10:40:33+02:00',
#              'GewijzigdOp@odata.type': '#DateTimeOffset',
#              'Id': '65129918-f256-4975-9da4-488da34d6695',
#              'Id@odata.type': '#Guid',
#              'NaamEN': 'Party for Freedom',
#              'NaamNL': 'Partij voor de Vrijheid',
#              'Nummer': 2765,
#              'Stemming@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/Stemming/$ref',
#              'Stemming@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/Stemming',
#              'Verwijderd': False,
#              'ZaakActor@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/ZaakActor/$ref',
#              'ZaakActor@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Fractie(65129918-f256-4975-9da4-488da34d6695)/ZaakActor'},
#  'Fractie@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/FractieZetel(0d23189b-ead4-4576-8cbd-6db0ac1ccc04)/Fractie/$ref',
#  'Fractie@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/FractieZetel(0d23189b-ead4-4576-8cbd-6db0ac1ccc04)/Fractie',
#  'FractieZetelPersoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/FractieZetel(0d23189b-ead4-4576-8cbd-6db0ac1ccc04)/FractieZetelPersoon/$ref',
#  'FractieZetelPersoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/FractieZetel(0d23189b-ead4-4576-8cbd-6db0ac1ccc04)/FractieZetelPersoon',
#  'FractieZetelVacature@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/FractieZetel(0d23189b-ead4-4576-8cbd-6db0ac1ccc04)/FractieZetelVacature/$ref',
#  'FractieZetelVacature@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/FractieZetel(0d23189b-ead4-4576-8cbd-6db0ac1ccc04)/FractieZetelVacature',
#  'Fractie_Id': '65129918-f256-4975-9da4-488da34d6695',
#  'Fractie_Id@odata.type': '#Guid',
#  'Gewicht': 10000,
#  'GewijzigdOp': '2019-04-01T10:40:33+02:00',
#  'GewijzigdOp@odata.type': '#DateTimeOffset',
#  'Id': '0d23189b-ead4-4576-8cbd-6db0ac1ccc04',
#  'Id@odata.type': '#Guid',
#  'Verwijderd': False}

# %%
# deze link doet het ook
url = '/Persoon?$orderby=Achternaam&$filter=FractieZetelPersoon/any(a:a/TotEnMet%20eq%20null)&$expand=FractieZetelPersoon($expand=FractieZetel($expand=Fractie))&$count=true'

# %%
base = 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/'
url = '/Persoon?'
end = '&$count=true&$format=application/json;odata.metadata=full'
response = urllib.request.urlopen(base+url+end)
data = response.read()      # a `bytes` object
data = json.loads(data)

# %%
for k in data['value'][1].keys():
    if '@odata.associationLink' in k: print(k)
# Out:
# ActiviteitActor@odata.associationLink
# ZaakActor@odata.associationLink
# DocumentActor@odata.associationLink
# CommissieZetelVastPersoon@odata.associationLink
# CommissieZetelVervangerPersoon@odata.associationLink
# FractieZetelPersoon@odata.associationLink
# PersoonGeschenk@odata.associationLink
# PersoonNevenfunctie@odata.associationLink
# PersoonContactinformatie@odata.associationLink
# PersoonLoopbaan@odata.associationLink
# PersoonOnderwijs@odata.associationLink
# PersoonReis@odata.associationLink
# Stemming@odata.associationLink

# %%
id = data['value'][0]['Id']
print(id)
# Out:
# e55ca731-e1aa-44c0-a5f3-0008c23976f7

# %%
base = 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/'
url = '/Persoon('+id+')/Resource'
end = '&$count=true&$format=application/json;odata.metadata=full'
response = urllib.request.urlopen(base+url)
data = response.read()      # a `bytes` object

# %%
base+url
# Out:
# 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0//Persoon(e55ca731-e1aa-44c0-a5f3-0008c23976f7)/Resource'

# %%
from IPython.display import Image 
Image(data)

# %%
base = 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/'
url = '/Persoon?$filter=PersoonGeschenk/any(a:a%20ne%20null)&$expand=PersoonGeschenk($count=true;$top=200)'
end = '&$count=true&$format=application/json;odata.metadata=full'
response = urllib.request.urlopen(base+url+end)
data = response.read()      # a `bytes` object
data = json.loads(data)

# %%
for k in data['value'][0].keys():
    if '@odata.associationLink' in k: print(k)
# Out:
# ActiviteitActor@odata.associationLink
# ZaakActor@odata.associationLink
# DocumentActor@odata.associationLink
# CommissieZetelVastPersoon@odata.associationLink
# CommissieZetelVervangerPersoon@odata.associationLink
# FractieZetelPersoon@odata.associationLink
# PersoonNevenfunctie@odata.associationLink
# PersoonContactinformatie@odata.associationLink
# PersoonLoopbaan@odata.associationLink
# PersoonOnderwijs@odata.associationLink
# PersoonReis@odata.associationLink
# Stemming@odata.associationLink
# PersoonGeschenk@odata.associationLink

# %%
data['value'][0]
# Out:
# {'@odata.type': '#TK.DA.GGM.OData.Persoon',
#  '@odata.id': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)',
#  '@odata.editLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)',
#  'Id@odata.type': '#Guid',
#  'Id': '1c889902-6ede-427c-8682-000f683fffaa',
#  'Nummer': 2491,
#  'Titels': 'MA',
#  'Initialen': 'M.',
#  'Tussenvoegsel': None,
#  'Achternaam': 'Agema',
#  'Voornamen': 'Marie-Fleur',
#  'Roepnaam': 'Fleur',
#  'Geslacht': 'vrouw',
#  'Functie': 'Tweede Kamerlid',
#  'Geboortedatum@odata.type': '#DateTimeOffset',
#  'Geboortedatum': '1976-09-16T00:00:00+02:00',
#  'Geboorteplaats': 'Purmerend',
#  'Geboorteland': 'Nederland',
#  'Overlijdensdatum': None,
#  'Overlijdensplaats': None,
#  'Woonplaats': 'Den Haag',
#  'Land': 'NL',
#  'ContentType': 'image/jpeg',
#  'ContentLength': 34744,
#  'GewijzigdOp@odata.type': '#DateTimeOffset',
#  'GewijzigdOp': '2019-04-01T10:40:33+02:00',
#  'ApiGewijzigdOp@odata.type': '#DateTimeOffset',
#  'ApiGewijzigdOp': '2019-04-01T12:48:10.857Z',
#  'Verwijderd': False,
#  'ActiviteitActor@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/ActiviteitActor/$ref',
#  'ActiviteitActor@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/ActiviteitActor',
#  'ZaakActor@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/ZaakActor/$ref',
#  'ZaakActor@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/ZaakActor',
#  'DocumentActor@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/DocumentActor/$ref',
#  'DocumentActor@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/DocumentActor',
#  'CommissieZetelVastPersoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/CommissieZetelVastPersoon/$ref',
#  'CommissieZetelVastPersoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/CommissieZetelVastPersoon',
#  'CommissieZetelVervangerPersoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/CommissieZetelVervangerPersoon/$ref',
#  'CommissieZetelVervangerPersoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/CommissieZetelVervangerPersoon',
#  'FractieZetelPersoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/FractieZetelPersoon/$ref',
#  'FractieZetelPersoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/FractieZetelPersoon',
#  'PersoonNevenfunctie@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonNevenfunctie/$ref',
#  'PersoonNevenfunctie@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonNevenfunctie',
#  'PersoonContactinformatie@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonContactinformatie/$ref',
#  'PersoonContactinformatie@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonContactinformatie',
#  'PersoonLoopbaan@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonLoopbaan/$ref',
#  'PersoonLoopbaan@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonLoopbaan',
#  'PersoonOnderwijs@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonOnderwijs/$ref',
#  'PersoonOnderwijs@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonOnderwijs',
#  'PersoonReis@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonReis/$ref',
#  'PersoonReis@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonReis',
#  'Stemming@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/Stemming/$ref',
#  'Stemming@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/Stemming',
#  'PersoonGeschenk@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonGeschenk/$ref',
#  'PersoonGeschenk@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonGeschenk',
#  'PersoonGeschenk@odata.count': 3,
#  'PersoonGeschenk@odata.type': '#Collection(TK.DA.GGM.OData.PersoonGeschenk)',
#  'PersoonGeschenk': [{'@odata.type': '#TK.DA.GGM.OData.PersoonGeschenk',
#    '@odata.id': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(687bd8ed-0698-443c-9845-ee4804f659b5)',
#    '@odata.editLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(687bd8ed-0698-443c-9845-ee4804f659b5)',
#    'Id@odata.type': '#Guid',
#    'Id': '687bd8ed-0698-443c-9845-ee4804f659b5',
#    'Omschrijving': 'Ontvangen van Boom uitgevers Amsterdam drie boeken: Montesquieu, over de geest van de wetten (waarde €64,50); Mill over de vrijheid (waarde €18,50) en Pascal Bruckner, Tirannie van het berouw (€23,90), Totale waarde €106,90.',
#    'Datum@odata.type': '#DateTimeOffset',
#    'Datum': '2008-09-30T00:00:00+02:00',
#    'GewijzigdOp@odata.type': '#DateTimeOffset',
#    'GewijzigdOp': '2019-04-01T10:40:33+02:00',
#    'ApiGewijzigdOp@odata.type': '#DateTimeOffset',
#    'ApiGewijzigdOp': '2019-04-01T12:48:18.747Z',
#    'Verwijderd': False,
#    'Persoon_Id@odata.type': '#Guid',
#    'Persoon_Id': '1c889902-6ede-427c-8682-000f683fffaa',
#    'Persoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(687bd8ed-0698-443c-9845-ee4804f659b5)/Persoon/$ref',
#    'Persoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(687bd8ed-0698-443c-9845-ee4804f659b5)/Persoon'},
#   {'@odata.type': '#TK.DA.GGM.OData.PersoonGeschenk',
#    '@odata.id': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(e1fde71d-d94e-4344-bec8-f2b0e93d731c)',
#    '@odata.editLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(e1fde71d-d94e-4344-bec8-f2b0e93d731c)',
#    'Id@odata.type': '#Guid',
#    'Id': 'e1fde71d-d94e-4344-bec8-f2b0e93d731c',
#    'Omschrijving': 'Ontvangen van De Landelijke Huisartsen Vereniging na een debat op 19 mei 2010 een thermometer en een bloeddrukmeter.',
#    'Datum@odata.type': '#DateTimeOffset',
#    'Datum': '2010-05-19T00:00:00+02:00',
#    'GewijzigdOp@odata.type': '#DateTimeOffset',
#    'GewijzigdOp': '2019-04-01T10:40:33+02:00',
#    'ApiGewijzigdOp@odata.type': '#DateTimeOffset',
#    'ApiGewijzigdOp': '2019-04-01T12:48:18.967Z',
#    'Verwijderd': False,
#    'Persoon_Id@odata.type': '#Guid',
#    'Persoon_Id': '1c889902-6ede-427c-8682-000f683fffaa',
#    'Persoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(e1fde71d-d94e-4344-bec8-f2b0e93d731c)/Persoon/$ref',
#    'Persoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(e1fde71d-d94e-4344-bec8-f2b0e93d731c)/Persoon'},
#   {'@odata.type': '#TK.DA.GGM.OData.PersoonGeschenk',
#    '@odata.id': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(6bb50b95-5412-4de1-9433-f432857640d8)',
#    '@odata.editLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(6bb50b95-5412-4de1-9433-f432857640d8)',
#    'Id@odata.type': '#Guid',
#    'Id': '6bb50b95-5412-4de1-9433-f432857640d8',
#    'Omschrijving': 'Ontvangen van Koninklijke Horeca Nederland na het debat in Dudok op 18 mei 2010 2 cadeaubonnen à €100,-- per stuk van Alliance Gastronomique.',
#    'Datum@odata.type': '#DateTimeOffset',
#    'Datum': '2010-05-18T00:00:00+02:00',
#    'GewijzigdOp@odata.type': '#DateTimeOffset',
#    'GewijzigdOp': '2019-04-01T10:40:33+02:00',
#    'ApiGewijzigdOp@odata.type': '#DateTimeOffset',
#    'ApiGewijzigdOp': '2019-04-01T12:48:18.577Z',
#    'Verwijderd': False,
#    'Persoon_Id@odata.type': '#Guid',
#    'Persoon_Id': '1c889902-6ede-427c-8682-000f683fffaa',
#    'Persoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(6bb50b95-5412-4de1-9433-f432857640d8)/Persoon/$ref',
#    'Persoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(6bb50b95-5412-4de1-9433-f432857640d8)/Persoon'}],
#  '#TK.DA.GGM.OData.Resource': {'title': 'Resource',
#   'target': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/TK.DA.GGM.OData.Resource()'}}

# %%
data['@odata.count']
# Out:
# 390

# %%
data['value'][0]
# Out:
# {'@odata.type': '#TK.DA.GGM.OData.Persoon',
#  '@odata.id': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)',
#  '@odata.editLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)',
#  'Id@odata.type': '#Guid',
#  'Id': '1c889902-6ede-427c-8682-000f683fffaa',
#  'Nummer': 2491,
#  'Titels': 'MA',
#  'Initialen': 'M.',
#  'Tussenvoegsel': None,
#  'Achternaam': 'Agema',
#  'Voornamen': 'Marie-Fleur',
#  'Roepnaam': 'Fleur',
#  'Geslacht': 'vrouw',
#  'Functie': 'Tweede Kamerlid',
#  'Geboortedatum@odata.type': '#DateTimeOffset',
#  'Geboortedatum': '1976-09-16T00:00:00+02:00',
#  'Geboorteplaats': 'Purmerend',
#  'Geboorteland': 'Nederland',
#  'Overlijdensdatum': None,
#  'Overlijdensplaats': None,
#  'Woonplaats': 'Den Haag',
#  'Land': 'NL',
#  'ContentType': 'image/jpeg',
#  'ContentLength': 34744,
#  'GewijzigdOp@odata.type': '#DateTimeOffset',
#  'GewijzigdOp': '2019-04-01T10:40:33+02:00',
#  'ApiGewijzigdOp@odata.type': '#DateTimeOffset',
#  'ApiGewijzigdOp': '2019-04-01T12:48:10.857Z',
#  'Verwijderd': False,
#  'ActiviteitActor@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/ActiviteitActor/$ref',
#  'ActiviteitActor@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/ActiviteitActor',
#  'ZaakActor@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/ZaakActor/$ref',
#  'ZaakActor@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/ZaakActor',
#  'DocumentActor@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/DocumentActor/$ref',
#  'DocumentActor@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/DocumentActor',
#  'CommissieZetelVastPersoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/CommissieZetelVastPersoon/$ref',
#  'CommissieZetelVastPersoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/CommissieZetelVastPersoon',
#  'CommissieZetelVervangerPersoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/CommissieZetelVervangerPersoon/$ref',
#  'CommissieZetelVervangerPersoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/CommissieZetelVervangerPersoon',
#  'FractieZetelPersoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/FractieZetelPersoon/$ref',
#  'FractieZetelPersoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/FractieZetelPersoon',
#  'PersoonNevenfunctie@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonNevenfunctie/$ref',
#  'PersoonNevenfunctie@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonNevenfunctie',
#  'PersoonContactinformatie@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonContactinformatie/$ref',
#  'PersoonContactinformatie@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonContactinformatie',
#  'PersoonLoopbaan@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonLoopbaan/$ref',
#  'PersoonLoopbaan@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonLoopbaan',
#  'PersoonOnderwijs@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonOnderwijs/$ref',
#  'PersoonOnderwijs@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonOnderwijs',
#  'PersoonReis@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonReis/$ref',
#  'PersoonReis@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonReis',
#  'Stemming@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/Stemming/$ref',
#  'Stemming@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/Stemming',
#  'PersoonGeschenk@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonGeschenk/$ref',
#  'PersoonGeschenk@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/PersoonGeschenk',
#  'PersoonGeschenk@odata.count': 3,
#  'PersoonGeschenk@odata.type': '#Collection(TK.DA.GGM.OData.PersoonGeschenk)',
#  'PersoonGeschenk': [{'@odata.type': '#TK.DA.GGM.OData.PersoonGeschenk',
#    '@odata.id': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(687bd8ed-0698-443c-9845-ee4804f659b5)',
#    '@odata.editLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(687bd8ed-0698-443c-9845-ee4804f659b5)',
#    'Id@odata.type': '#Guid',
#    'Id': '687bd8ed-0698-443c-9845-ee4804f659b5',
#    'Omschrijving': 'Ontvangen van Boom uitgevers Amsterdam drie boeken: Montesquieu, over de geest van de wetten (waarde €64,50); Mill over de vrijheid (waarde €18,50) en Pascal Bruckner, Tirannie van het berouw (€23,90), Totale waarde €106,90.',
#    'Datum@odata.type': '#DateTimeOffset',
#    'Datum': '2008-09-30T00:00:00+02:00',
#    'GewijzigdOp@odata.type': '#DateTimeOffset',
#    'GewijzigdOp': '2019-04-01T10:40:33+02:00',
#    'ApiGewijzigdOp@odata.type': '#DateTimeOffset',
#    'ApiGewijzigdOp': '2019-04-01T12:48:18.747Z',
#    'Verwijderd': False,
#    'Persoon_Id@odata.type': '#Guid',
#    'Persoon_Id': '1c889902-6ede-427c-8682-000f683fffaa',
#    'Persoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(687bd8ed-0698-443c-9845-ee4804f659b5)/Persoon/$ref',
#    'Persoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(687bd8ed-0698-443c-9845-ee4804f659b5)/Persoon'},
#   {'@odata.type': '#TK.DA.GGM.OData.PersoonGeschenk',
#    '@odata.id': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(e1fde71d-d94e-4344-bec8-f2b0e93d731c)',
#    '@odata.editLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(e1fde71d-d94e-4344-bec8-f2b0e93d731c)',
#    'Id@odata.type': '#Guid',
#    'Id': 'e1fde71d-d94e-4344-bec8-f2b0e93d731c',
#    'Omschrijving': 'Ontvangen van De Landelijke Huisartsen Vereniging na een debat op 19 mei 2010 een thermometer en een bloeddrukmeter.',
#    'Datum@odata.type': '#DateTimeOffset',
#    'Datum': '2010-05-19T00:00:00+02:00',
#    'GewijzigdOp@odata.type': '#DateTimeOffset',
#    'GewijzigdOp': '2019-04-01T10:40:33+02:00',
#    'ApiGewijzigdOp@odata.type': '#DateTimeOffset',
#    'ApiGewijzigdOp': '2019-04-01T12:48:18.967Z',
#    'Verwijderd': False,
#    'Persoon_Id@odata.type': '#Guid',
#    'Persoon_Id': '1c889902-6ede-427c-8682-000f683fffaa',
#    'Persoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(e1fde71d-d94e-4344-bec8-f2b0e93d731c)/Persoon/$ref',
#    'Persoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(e1fde71d-d94e-4344-bec8-f2b0e93d731c)/Persoon'},
#   {'@odata.type': '#TK.DA.GGM.OData.PersoonGeschenk',
#    '@odata.id': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(6bb50b95-5412-4de1-9433-f432857640d8)',
#    '@odata.editLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(6bb50b95-5412-4de1-9433-f432857640d8)',
#    'Id@odata.type': '#Guid',
#    'Id': '6bb50b95-5412-4de1-9433-f432857640d8',
#    'Omschrijving': 'Ontvangen van Koninklijke Horeca Nederland na het debat in Dudok op 18 mei 2010 2 cadeaubonnen à €100,-- per stuk van Alliance Gastronomique.',
#    'Datum@odata.type': '#DateTimeOffset',
#    'Datum': '2010-05-18T00:00:00+02:00',
#    'GewijzigdOp@odata.type': '#DateTimeOffset',
#    'GewijzigdOp': '2019-04-01T10:40:33+02:00',
#    'ApiGewijzigdOp@odata.type': '#DateTimeOffset',
#    'ApiGewijzigdOp': '2019-04-01T12:48:18.577Z',
#    'Verwijderd': False,
#    'Persoon_Id@odata.type': '#Guid',
#    'Persoon_Id': '1c889902-6ede-427c-8682-000f683fffaa',
#    'Persoon@odata.associationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(6bb50b95-5412-4de1-9433-f432857640d8)/Persoon/$ref',
#    'Persoon@odata.navigationLink': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/PersoonGeschenk(6bb50b95-5412-4de1-9433-f432857640d8)/Persoon'}],
#  '#TK.DA.GGM.OData.Resource': {'title': 'Resource',
#   'target': 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Persoon(1c889902-6ede-427c-8682-000f683fffaa)/TK.DA.GGM.OData.Resource()'}}

# %% [markdown]
# $$$Geschenken

# %%
# fractieleden met aantal geschenken en lid van partij
base = 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/'
url = '/Persoon?$filter=PersoonGeschenk/any(a:a%20ne%20null)%20and%20FractieZetelPersoon/any(a:a/TotEnMet%20eq%20null)&$expand=FractieZetelPersoon($expand=FractieZetel($expand=Fractie)),PersoonGeschenk($count=true;$top=200)'
end = '&$count=true&$format=application/json;odata.metadata=full'
response = urllib.request.urlopen(base+url+end)
data = response.read()      # a `bytes` object
data = json.loads(data)
print(data.keys())
if '@odata.nextLink' in data.keys():
    response2 = urllib.request.urlopen(data['@odata.nextLink'])
    data2 = response2.read()
    data2 = json.loads(data2)
    data['value'] = data['value'] + data2['value']

test = {i['Achternaam']:[i['PersoonGeschenk@odata.count'],i['FractieZetelPersoon'][0]['FractieZetel']['Fractie']['Afkorting']] for i in data['value']}
newdict = {}
for k in test.keys():
    newdict.setdefault(test[k][1], []).append(test[k][0])
# Out:
# dict_keys(['@odata.context', '@odata.count', 'value'])

# %%
for i in newdict.keys():
    print (i,np.median(newdict[i]))
# Out:
# PVV 1.0
# CDA 8.0
# VVD 22.0
# CU 10.0
# GL 6.0
# SP 3.0
# PvdA 4.0
# D66 7.5
# SGP 20.0
# 50PLUS 8.5
# 50PLUS/Baay-Timmerman 120.0
# PvdD 7.0

# %%
from collections import OrderedDict
order = OrderedDict([(k,test[k]) for k in test.keys()])
order = OrderedDict(sorted(order.items(), key=lambda x: x[1][0],reverse=True))
order
# Out:
# OrderedDict([('Dijkstra', [200, 'VVD']),
#              ('Heerema', [190, 'VVD']),
#              ('Krol', [120, '50PLUS/Baay-Timmerman']),
#              ('Veldman', [63, 'VVD']),
#              ('Lodders', [56, 'VVD']),
#              ('Mulder', [55, 'VVD']),
#              ('Toorenburg', [53, 'CDA']),
#              ('Arib', [52, 'PvdA']),
#              ('Linde', [47, 'VVD']),
#              ('Harbers', [45, 'VVD']),
#              ('Weverling', [45, 'VVD']),
#              ('Geluk-Poortvliet', [37, 'CDA']),
#              ('Rutte', [36, 'VVD']),
#              ('Bisschop', [34, 'SGP']),
#              ('Nijkerken-de Haan', [33, 'VVD']),
#              ('Yeşilgöz-Zegerius', [32, 'VVD']),
#              ('Vries', [27, 'VVD']),
#              ('Kuiken', [26, 'PvdA']),
#              ('Koerhuis', [24, 'VVD']),
#              ('Tielen', [23, 'VVD']),
#              ('Koopmans', [23, 'VVD']),
#              ('Klaver', [23, 'GL']),
#              ('Ziengs', [21, 'VVD']),
#              ('Staaij', [20, 'SGP']),
#              ('Westerveld', [20, 'GL']),
#              ('Berg', [20, 'CDA']),
#              ('Laan-Geselschap', [19, 'VVD']),
#              ('Belhaj', [19, 'D66']),
#              ('Wout', [19, 'VVD']),
#              ('Geurts', [18, 'CDA']),
#              ('Bosman', [18, 'VVD']),
#              ('Weyenberg', [17, 'D66']),
#              ('Aartsen', [17, 'VVD']),
#              ('Wijngaarden', [16, 'VVD']),
#              ('Kwint', [16, 'SP']),
#              ('Diks', [15, 'GL']),
#              ('Bergkamp', [15, 'D66']),
#              ('Verhoeven', [14, 'D66']),
#              ('Bruins', [13, 'CU']),
#              ('Voordewind', [12, 'CU']),
#              ('Tellegen', [12, 'VVD']),
#              ('Rog', [12, 'CDA']),
#              ('Meenen', [11, 'D66']),
#              ('Thieme', [11, 'PvdD']),
#              ('Middendorp', [10, 'VVD']),
#              ('Segers', [10, 'CU']),
#              ('Diertens', [10, 'D66']),
#              ('Martels', [10, 'CDA']),
#              ('Boer', [10, 'D66']),
#              ('Leijten', [9, 'SP']),
#              ('Sazias', [9, '50PLUS']),
#              ('Dijkhoff', [9, 'VVD']),
#              ('Lee', [9, 'GL']),
#              ('Sienot', [9, 'D66']),
#              ('Heerma', [8, 'CDA']),
#              ('Molen', [8, 'CDA']),
#              ('Jetten', [8, 'D66']),
#              ('Brenk', [8, '50PLUS']),
#              ('Bosch', [8, 'VVD']),
#              ('El Yassini', [8, 'VVD']),
#              ('Gent', [7, 'VVD']),
#              ('Ellemeet', [7, 'GL']),
#              ('Ouwehand', [7, 'PvdD']),
#              ('Paternotte', [7, 'D66']),
#              ('Kröger', [6, 'GL']),
#              ('Smeulders', [6, 'GL']),
#              ('Dam', [6, 'CDA']),
#              ('Kuzu', [6, 'PvdA']),
#              ('Wörsdörfer', [5, 'VVD']),
#              ('Wiersma', [5, 'VVD']),
#              ('Ploumen', [5, 'PvdA']),
#              ('Sjoerdsma', [5, 'D66']),
#              ('Madlener', [5, 'PVV']),
#              ('Özütok', [4, 'GL']),
#              ('Helvert', [4, 'CDA']),
#              ('Karabulut', [4, 'SP']),
#              ('Öztürk', [4, 'PvdA']),
#              ('Nispen', [4, 'SP']),
#              ('Kuik', [4, 'CDA']),
#              ('Schonis', [4, 'D66']),
#              ('Eijs', [4, 'D66']),
#              ('Raemakers', [4, 'D66']),
#              ('Bromet', [4, 'GL']),
#              ('Hermans', [4, 'VVD']),
#              ('Agema', [3, 'PVV']),
#              ('Helder', [3, 'PVV']),
#              ('Amhaouch', [3, 'CDA']),
#              ('Nijboer', [3, 'PvdA']),
#              ('Kerstens', [3, 'PvdA']),
#              ('Asscher', [3, 'PvdA']),
#              ('Raak', [3, 'SP']),
#              ('Beckerman', [3, 'SP']),
#              ('Groot', [3, 'D66']),
#              ('Gerven', [2, 'SP']),
#              ('Omtzigt', [2, 'CDA']),
#              ('Futselaar', [2, 'SP']),
#              ('Hul', [2, 'PvdA']),
#              ('Peters', [2, 'CDA']),
#              ('Buitenweg', [2, 'GL']),
#              ('Groothuizen', [2, 'D66']),
#              ('Wilders', [2, 'PVV']),
#              ('Dik-Faber', [2, 'CU']),
#              ('Ojik', [2, 'GL']),
#              ('Slootweg', [1, 'CDA']),
#              ('Fritsma', [1, 'PVV']),
#              ('Drost', [1, 'CU']),
#              ('Graus', [1, 'PVV']),
#              ('Dijk', [1, 'PVV']),
#              ('Bosma', [1, 'PVV']),
#              ('Roon', [1, 'PVV']),
#              ('Marijnissen', [1, 'SP']),
#              ('Sneller', [1, 'D66']),
#              ('Wassenberg', [1, 'PvdD']),
#              ('Stoffer', [1, 'SGP']),
#              ('Dijck', [1, 'PVV']),
#              ('Bouali', [1, 'D66'])])

# %%
from pprint import pprint
for k in data['value']:
    if k['Achternaam']=='Dijkhoff' or k['Achternaam']=='Bisschop':
        
        geschenken = k['PersoonGeschenk']
        for g in geschenken:
            if 'boek' not in g['Omschrijving'] and 'wijn' not in g['Omschrijving']:
                if len(re.findall(r'€\d\d\d', g['Omschrijving']))>0:
                    print(k['FractieZetelPersoon'][0]['FractieZetel']['Fractie']['Afkorting'],k['Achternaam'],g['Omschrijving'][14:])
# Opvallend SGP Staaij die de SGP twv 3000 leegtrekt
# Opvallend Dijkhoff die 5000 binnentikt met verkiezing best geklede man
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-75b0497b5675> in <module>
#       6         for g in geschenken:
#       7             if 'boek' not in g['Omschrijving'] and 'wijn' not in g['Omschrijving']:
# ----> 8                 if len(re.findall(r'€\d\d\d', g['Omschrijving']))>0:
#       9                     print(k['FractieZetelPersoon'][0]['FractieZetel']['Fractie']['Afkorting'],k['Achternaam'],g['Omschrijving'][14:])
#      10 # Opvallend SGP Staaij die de SGP twv 3000 leegtrekt
#
# NameError: name 're' is not defined

# %%
base = 'https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/'
url = '/Persoon?$filter=PersoonNevenFunctie/any(a:a%20ne%20null)&$expand=PersoonNevenFunctie($expand=PersoonNevenFunctieInkomsten),FractieZetelPersoon($expand=FractieZetel($expand=Fractie))'
end = '&$count=true&$format=application/json;odata.metadata=full'
response = urllib.request.urlopen(base+url)
data = response.read()      # a `bytes` object
data = json.loads(data)

# %%
df = pd.DataFrame(data['value'])

# %%
df.head()

# %%
datalist = []
c=0
for p in data['value']:
    for n in p['PersoonNevenfunctie']:
        if n['VergoedingSoort']=='Bezoldigd':
            if len(n['PersoonNevenfunctieInkomsten'])>0:
                for i in n['PersoonNevenfunctieInkomsten']:
                    i['Initialen']=p['Initialen']
                    i['Tussenvoegsel']=p['Tussenvoegsel']
                    i['Roepnaam']=p['Roepnaam']
                    i['Achternaam']=p['Achternaam']
                    i['Geboortedatum']=p['Geboortedatum']
                    i['Omschrijving']=n['Omschrijving']
                    i['PeriodeVan']=n['PeriodeVan']
                    i['PeriodeTotEnMet']=n['PeriodeTotEnMet']
                    i['IsActief']=n['IsActief']
                    i['VergoedingSoort']=n['VergoedingSoort']
                    i['VergoedingToelichting']=n['VergoedingToelichting']
                    i['Fractie']=p['FractieZetelPersoon'][0]['FractieZetel']['Fractie']['Afkorting']
                    if i['Bedrag']:
                        i['Totaal']=i['Bedrag']
                    else:
                        i['Totaal']= 0
                    if i['Frequentie']=='Per maand':
                        i['Totaal']*=12
                    if i['BedragValuta']=='USD':
                        i['Totaal']*=0.890270589   
                    if i['FrequentieBeschrijving']=='4 keer per jaar' or i['FrequentieBeschrijving']=='4 a 5 keer per jaar' :
                        i['Totaal']*=12   
                    datalist.append(i)
            else:
                print(c)
                print (len(n['PersoonNevenfunctieInkomsten']))
                c+=1
                pprint(n)

# %%
income = pd.DataFrame(datalist)
pd.options.display.max_rows=500
income.sort_values(by=['Bedrag'],ascending = False, inplace=True)
column_order = ['Initialen','Roepnaam', 'Tussenvoegsel','Achternaam', 'Bedrag', 'BedragValuta','BedragSoort', 'BedragVoorvoegsel', 'Fractie',
 'Frequentie', 'FrequentieBeschrijving',  'Jaar', 
 'Omschrijving', 'Opmerking',  'PeriodeVan','PeriodeTotEnMet',
  'VergoedingToelichting','BedragAchtervoegsel','VergoedingSoort', 'Geboortedatum','Nevenfunctie_Id','Id', 'IsActief', 
 'Verwijderd','ApiGewijzigdOp','GewijzigdOp']
column_order = ['Initialen','Roepnaam', 'Tussenvoegsel','Achternaam', 'Bedrag', 'BedragValuta','BedragSoort', 'BedragVoorvoegsel', 'Fractie',
 'Frequentie', 'FrequentieBeschrijving',  'Jaar', 
 'Omschrijving', 'Opmerking',  'PeriodeVan','PeriodeTotEnMet','IsActief',
  'VergoedingToelichting','Totaal']

income = income[column_order]
#income.query("Achternaam == 'Elias'")
income

# %%
for c in income.columns:
    if c in ['BedragSoort ', 'BedragValuta', 'Frequentie', 'BedragAchtervoegsel','BedragVoorvoegsel', 'FrequentieBeschrijving', 'IsActief', 'Jaar' ]  :
        print('\n',c,income[c].value_counts())

# %%
income.describe(include='all')

# %%
pd.options.display.max_colwidth=200
#income.query("Achternaam == 'Koopmans'")
#income[:50]

# %%
from pprint import pprint 
for p in data['value']:
    if p['Achternaam']=='Koopmans':
        pprint(p)

# %%
a = pd.DataFrame(income.groupby(['Jaar','Fractie'])['Bedrag'].sum())
source = a
a.head()

# %%
source.reset_index(inplace=True)
print(source)
altair.Chart(source).mark_bar().encode(
    x='Jaar',
    y='Bedrag',
    color='Fractie'
)

# %%
income.query("Jaar =='2018'")

# %%
income.query("Achternaam =='Ziengs'")

# %%
for p in data['value']:
    if p['Achternaam'] == 'Ziengs':
        pprint(p)

# %%
for p in data['value']:
    if p['Achternaam']!= 'Ziengs':
        for n in p['PersoonNevenfunctie']:

            if n['Omschrijving']=='Directeur Nederlandse Zuivel Organisaties':
                pprint(p)
